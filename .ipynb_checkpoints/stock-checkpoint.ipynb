# %%
import pandas as pd
import numpy as np
import math
import pandas_datareader as web
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
import panel as pn
pn.extension('tabulator')
# pn.extension(template='fast-list')
import hvplot.pandas
from ipywidgets import Dropdown
import datetime
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
# from matplotlib.figure import Figure
# from matplotlib.backends.backend_agg import FigureCanvas

# %%
from panel.interact import interact

# %%
# ticker.value
# df = web.DataReader('AAPL', data_source="yahoo", start="2015-01-01", end="2022-05-01" )
# df

# %%
# df = web.DataReader(ticker.value, data_source="yahoo", start="2015-01-01", end="2022-05-01" )
# df =  create_plot()
# df
# idf = df.interactive()
# year_slider = pn.widgets.IntSlider(name = 'year slider', start=2015, end=2020,step=1, value=2015)
# df['year'] = df.index.year
# df['date'] = df.index

# share_pipeline = (
#     idf[
#         (idf.year <= year_slider)]
# )

# %%
# def dropdown_eventhandler(change):
#     global df
#     df  = web.DataReader(change.new, data_source="yahoo", start="2015-01-01", end="2022-05-01" )
#     return df

# option_list = ['AAPL', 'FB', 'GOOG', 'IBM', 'MSFT']
# dropdown = Dropdown(description="Choose one:", options=option_list)
# dropdown.observe(dropdown_eventhandler, names='value')
# display(dropdown)

# %%
# idf = df.interactive()
# year_slider = pn.widgets.IntSlider(name = 'year slider', start=2015, end=2020,step=1, value=2015)
# df['year'] = df.index.year
# df['date'] = df.index
# share_plot = share_pipeline.hvplot(x ='date' , y=yaxis_share, line_width=2, title="Plot Data")
# share_table = share_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')

# %%
df_widget = pn.widgets.Tabulator(df, height=300)
# Out:
# Tabulator(height=300, pagination='local', value=              ...)

# %%
# share_plot = share_pipeline.hvplot(x ='date' , y=yaxis_share, line_width=2, title="Plot Data")
# share_table = share_pipeline.pipe(pn.widgets.Tabulator, pagination='remote', page_size = 10, sizing_mode='stretch_width')

# %%
yaxis_share = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['High', 'Close', 'Low'],
    button_type='success'
)

# %%
start = pn.widgets.DatePicker(name='Date Picker',value =datetime.date(2020,1,1) )
end = pn.widgets.DatePicker(name='Date Picker')
print(start)
print(end)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Shubham\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3397, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Shubham\AppData\Local\Temp\ipykernel_1860\3847287021.py", line 1, in <cell line: 1>
#     start = pn.widgets.DatePicker(name='Date Picker',value = 2020/10/10 )
#   File "C:\Users\Shubham\AppData\Local\Programs\Python\Python310\lib\site-packages\panel\widgets\base.py", line 54, in __init__
#     super().__init__(**params)
#   File "C:\Users\Shubham\AppData\Local\Programs\Python\Python310\lib\site-packages\panel\reactive.py", line 82, in __init__
#     super().__init__(**params)
#   File "C:\Users\Shubham\AppData\Local\Programs\Python\Python310\lib\site-packages\panel\viewable.py", line 544, in __init__
#     super().__init__(**params)
# ...

# %%
tickers = ['AAPL', 'FB', 'GOOG', 'IBM', 'MSFT']
start = pn.widgets.DatePicker(name='Date Picker')
end = pn.widgets.DatePicker(name='Date Picker')

def get_df(ticker, window_size, start, end):
    df = web.DataReader(ticker, data_source="yahoo", start=start, end=end )
    df['Date'] = pd.to_datetime(df.index)
    return df.set_index('Date').rolling(window=window_size).mean().reset_index()

def get_plot(ticker, share_values,start,end,window_size):
    df = get_df(ticker, start, end, window_size)
    return df.hvplot.line('Date', share_values , grid=True, height=300, width=700)

# %%
interact = pn.interact(get_plot, ticker=tickers, share_values = yaxis_share , start = start , end = end ,window_size=(1, 21, 5))
# Out:
# ---------------------------------------------------------------------------
# OutOfBoundsDatetime                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\datetimes.py:2211, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2210 try:
# -> 2211     values, tz_parsed = conversion.datetime_to_datetime64(data.ravel("K"))
#    2212     # If tzaware, these values represent unix timestamps, so we
#    2213     #  return them as i8 to distinguish from wall times
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\conversion.pyx:358, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\tslibs\np_datetime.pyx:120, in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# ...

# %%
jpg_pane = pn.pane.JPG('stock.jpg', width=500)

# %%
template = pn.template.FastListTemplate(
    title='Stock Market Prediction', 
    sidebar=[pn.pane.Markdown("# Stock Market Prediction"), 
             pn.pane.Markdown("#### The intelligent investor is a realist who sells to optimists and buys from pessimists."), 
             # jpg_pane,
             pn.pane.Markdown("## Settings"),   
             interact[0] ],
    main=[
        # pn.Row(pn.Column(yaxis_share, 
        #                    share_plot.panel(width=700), margin=(0,25)), 
        #          share_table.panel(width=500)),
        pn.Row(pn.Column(interact[1]),
             pn.Column(df_widget)
              ),
   ],
       
    accent_base_color="#88d8b0",
    header_background="#88d8b0",
)
# template.show()

# %%
template.servable()
template.show()
# Out:
# Launching server at http://localhost:62410
